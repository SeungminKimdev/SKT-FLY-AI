# %% [markdown]
# # Pandas

# %% [markdown]
# ## Series

# %%
import pandas as pd

pd.__version__
# Out:
# '2.0.3'

# %%
s = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'], name = 'Grade')
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: Grade, dtype: int64

# %%
print(s.name)
print(s.index)
print(s.shape)
print(s.values)
# Out:
# Grade
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# (5,)
# [1 2 3 4 5]

# %%
s + 5 # 각 원소에 다 더해줌, 사칙연산 가능
# Out:
# a     6
# b     7
# c     8
# d     9
# e    10
# Name: Grade, dtype: int64

# %%
s.isna() # nan 값 확인
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# Name: Grade, dtype: bool

# %%
s > 2 # 연산 가능
# Out:
# a    False
# b    False
# c     True
# d     True
# e     True
# Name: Grade, dtype: bool

# %% [markdown]
# ## DataFrame

# %%
info = {
    'Name':['Jackson', 'Emma', 'Noah', 'James'],
    'Weight':[68, 74, 77, 78],
    'Option':[True, True, False, False],
    'Rate':[0.21, 1.1, 0.89, 0.91],
    'Type':['A','A','C','C']
}

df = pd.DataFrame(info) #데이터 프레임 생성

# %%
df.head(5)
# Out:
#       Name  Weight  Option  Rate Type
# 0  Jackson      68    True  0.21    A
# 1     Emma      74    True  1.10    A
# 2     Noah      77   False  0.89    C
# 3    James      78   False  0.91    C

# %%
df.shape
# Out:
# (4, 5)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Weight', 'Option', 'Rate', 'Type'], dtype='object')

# %%
df = pd.read_csv("https://raw.githubusercontent.com/devdio/flyai_datasets/main/vgsalesGlobale.csv", encoding='utf-8')

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA Sales',
#        'EU Sales', 'JP Sales', 'Other Sales', 'Global Sales'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA Sales  EU Sales  JP Sales  Other Sales  Global Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.sample(3)
# Out:
#         Rank                          Name Platform    Year      Genre  \
# 8692    8694  The Walking Dead: Season One     XOne  2014.0  Adventure
# 5864    5866               Zoo Tycoon 2 DS       DS  2008.0   Strategy
# 11889  11891                         Speed      Wii  2010.0     Racing
#
#             Publisher  NA Sales  EU Sales  JP Sales  Other Sales  Global Sales
# 8692   Telltale Games      0.08      0.06       0.0         0.01          0.16
# 5864              THQ      0.24      0.03       0.0         0.02          0.30
# 11889         Unknown      0.04      0.02       0.0         0.01          0.07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA Sales      16598 non-null  float64
#  7   EU Sales      16598 non-null  float64
#  8   JP Sales      16598 non-null  float64
#  9   Other Sales   16598 non-null  float64
#  10  Global Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                Rank          Year      NA Sales      EU Sales      JP Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other Sales  Global Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.isna().sum() # 결측값 표시
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA Sales          0
# EU Sales          0
# JP Sales          0
# Other Sales       0
# Global Sales      0
# dtype: int64

# %%
df.isna().any(axis=1) # any = 하나라도 있는지
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16593    False
# 16594    False
# 16595    False
# 16596    False
# 16597    False
# Length: 16598, dtype: bool

# %%
df[df.isna().any(axis=1)]
# Out:
#         Rank                             Name Platform    Year         Genre  \
# 179      180                  Madden NFL 2004      PS2     NaN        Sports
# 377      378                 FIFA Soccer 2004      PS2     NaN        Sports
# 431      432       LEGO Batman: The Videogame      Wii     NaN        Action
# 470      471       wwe Smackdown vs. Raw 2006      PS2     NaN      Fighting
# 607      608                   Space Invaders     2600     NaN       Shooter
# ...      ...                              ...      ...     ...           ...
# 16427  16430                     Virtua Quest       GC     NaN  Role-Playing
# 16493  16496                       The Smurfs      3DS     NaN        Action
# 16494  16497  Legends of Oz: Dorothy's Return      3DS  2014.0        Puzzle
# 16543  16546           Driving Simulator 2011       PC  2011.0        Racing
# 16553  16556                   Bound By Flame     X360  2014.0  Role-Playing
#
# ...

# %% [markdown]
# ## 컬럼선택

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA Sales',
#        'EU Sales', 'JP Sales', 'Other Sales', 'Global Sales'],
#       dtype='object')

# %%
df['Rank'] # Series 형태
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 16593    16596
# 16594    16597
# 16595    16598
# 16596    16599
# 16597    16600
# Name: Rank, Length: 16598, dtype: int64

# %%
df[['Rank','EU Sales']] # 두개 이상은 배열에 넣어서, DataFram 형태
# Out:
#         Rank  EU Sales
# 0          1     29.02
# 1          2      3.58
# 2          3     12.88
# 3          4     11.01
# 4          5      8.89
# ...      ...       ...
# 16593  16596      0.00
# 16594  16597      0.00
# 16595  16598      0.00
# 16596  16599      0.01
# 16597  16600      0.00
#
# [16598 rows x 2 columns]

# %%
df.columns = [col.lower().replace(' ','_') for col in df.columns] # 컬럼명 변경

# %%
df.head()
# Out:
#    rank                      name platform    year         genre publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df[df.global_sales > 40]
# Out:
#    rank               name platform    year     genre publisher  na_sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
#
#    eu_sales  jp_sales  other_sales  global_sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24

# %%
df[df.global_sales > 40]['eu_sales']
# Out:
# 0    29.02
# 1     3.58
# Name: eu_sales, dtype: float64

# %%
df[(df.global_sales > 40) | (df.jp_sales < 10)]
# Out:
#    rank               name platform    year     genre publisher  na_sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
#
#    eu_sales  jp_sales  other_sales  global_sales
# 0     29.02      3.77         8.46         82.74
# 1      3.58      6.81         0.77         40.24

# %%
df.loc[(df.global_sales > 40), ['jp_sales','na_sales']]
# Out:
#    jp_sales  na_sales
# 0      3.77     41.49
# 1      6.81     29.08

# %%
df.iloc[50:,3]
# Out:
# 50       1992.0
# 51       2008.0
# 52       1997.0
# 53       2011.0
# 54       2010.0
#           ...
# 16593    2002.0
# 16594    2003.0
# 16595    2008.0
# 16596    2010.0
# 16597    2003.0
# Name: year, Length: 16548, dtype: float64

# %%
df_num = df.select_dtypes(include=['number']) # 값이 숫자 데이터만 불러오기

# %%
df_num['global_sales_twice'] = df_num['global_sales'] * 2
df_num
# Out:
#         rank    year  na_sales  eu_sales  jp_sales  other_sales  global_sales  \
# 0          1  2006.0     41.49     29.02      3.77         8.46         82.74
# 1          2  1985.0     29.08      3.58      6.81         0.77         40.24
# 2          3  2008.0     15.85     12.88      3.79         3.31         35.82
# 3          4  2009.0     15.75     11.01      3.28         2.96         33.00
# 4          5  1996.0     11.27      8.89     10.22         1.00         31.37
# ...      ...     ...       ...       ...       ...          ...           ...
# 16593  16596  2002.0      0.01      0.00      0.00         0.00          0.01
# 16594  16597  2003.0      0.01      0.00      0.00         0.00          0.01
# 16595  16598  2008.0      0.00      0.00      0.00         0.00          0.01
# 16596  16599  2010.0      0.00      0.01      0.00         0.00          0.01
# 16597  16600  2003.0      0.01      0.00      0.00         0.00          0.01
#
#        global_sales_twice
# ...

# %%
df_num.drop(['global_sales'], axis=1, inplace=True)
# Out:
#         rank    year  na_sales  eu_sales  jp_sales  other_sales  \
# 0          1  2006.0     41.49     29.02      3.77         8.46
# 1          2  1985.0     29.08      3.58      6.81         0.77
# 2          3  2008.0     15.85     12.88      3.79         3.31
# 3          4  2009.0     15.75     11.01      3.28         2.96
# 4          5  1996.0     11.27      8.89     10.22         1.00
# ...      ...     ...       ...       ...       ...          ...
# 16593  16596  2002.0      0.01      0.00      0.00         0.00
# 16594  16597  2003.0      0.01      0.00      0.00         0.00
# 16595  16598  2008.0      0.00      0.00      0.00         0.00
# 16596  16599  2010.0      0.00      0.01      0.00         0.00
# 16597  16600  2003.0      0.01      0.00      0.00         0.00
#
#        global_sales_twice
# 0                  165.48
# 1                   80.48
# 2                   71.64
# 3                   66.00
# 4                   62.74
# ...                   ...
# ...

# %%
df.isna().sum(axis=0)
# Out:
# rank              0
# name              0
# platform          0
# year            271
# genre             0
# publisher        58
# na_sales          0
# eu_sales          0
# jp_sales          0
# other_sales       0
# global_sales      0
# dtype: int64

# %%
df['year'].fillna(0)
# Out:
# 0        2006.0
# 1        1985.0
# 2        2008.0
# 3        2009.0
# 4        1996.0
#           ...
# 16593    2002.0
# 16594    2003.0
# 16595    2008.0
# 16596    2010.0
# 16597    2003.0
# Name: year, Length: 16598, dtype: float64

# %%
df.isna().sum(axis=0)
# Out:
# rank              0
# name              0
# platform          0
# year            271
# genre             0
# publisher        58
# na_sales          0
# eu_sales          0
# jp_sales          0
# other_sales       0
# global_sales      0
# dtype: int64

# %%
df['publisher'].value_counts()
# Out:
# publisher
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Warp                               1
# New                                1
# Elite                              1
# Evolution Games                    1
# UIG Entertainment                  1
# Name: count, Length: 578, dtype: int64

# %%
df['publisher'] = df['publisher'].fillna('Electronic Arts')

# %%
df.isna().sum(axis=0)
# Out:
# rank              0
# name              0
# platform          0
# year            271
# genre             0
# publisher         0
# na_sales          0
# eu_sales          0
# jp_sales          0
# other_sales       0
# global_sales      0
# dtype: int64

# %%
df = df.dropna()
df.shape
# Out:
# (16327, 11)
